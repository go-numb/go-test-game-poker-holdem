# %%
import pandas as pd
from matplotlib import pyplot
import math
import numpy as np

# %%
df = pd.read_csv("./test.csv")

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': ' 11'}>],
#        [<Axes: title={'center': ' 3'}>, <Axes: >]], dtype=object)

# %%
df.describe()
# Out:
#                   0            11             3
# count  12999.000000  12999.000000  12999.000000
# mean    6500.000000      6.968382      2.499885
# std     3752.632409      3.749258      1.113768
# min        1.000000      1.000000      1.000000
# 25%     3250.500000      4.000000      2.000000
# 50%     6500.000000      7.000000      2.000000
# 75%     9749.500000     10.000000      3.000000
# max    12999.000000     13.000000      4.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12999 entries, 0 to 12998
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       12999 non-null  int64
#  1    11     12999 non-null  int64
#  2    3      12999 non-null  int64
# dtypes: int64(3)
# memory usage: 304.8 KB

# %%
df.columns = ["index", "number", "mark"]

# %%
df["number"].hist(bins=13)
# Out:
# <Axes: >

# %%
df["number"].unique()
df["number"].value_counts()
# Out:
# number
# 3     1045
# 6     1027
# 1     1014
# 8     1011
# 4     1004
# 11    1001
# 2     1000
# 13     999
# 5      992
# 10     990
# 9      986
# 12     985
# 7      945
# Name: count, dtype: int64

# %%
df["mark"].hist(bins=4)
# Out:
# <Axes: >

# %%
df["mark"].unique()
df["mark"].value_counts()
# Out:
# mark
# 2    3305
# 3    3257
# 4    3226
# 1    3211
# Name: count, dtype: int64
